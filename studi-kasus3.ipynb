# %%
import os
import seaborn as sns
import numpy as np
import cv2
import pickle

# %%
def haar(img):
    status = False
    face_roi = [] 

    # Load Haar Cascade classifier for face detection
    face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml') 

    # Convert the image to grayscale (required for face detection)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # Detect faces in the image using the face_cascade
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.5, minNeighbors=5) 

    # Draw bounding boxes around the detected faces and display the image
    for (x, y, w, h) in faces:
        # Draw a rectangle around the detected face
        face_roi = img[y:y+h, x:x+w]
        status = True
    return status,face_roi

# %%
#menentukan direktori/folder data citra yang akan dibuka
dirname = 'C:/Users/Reza/miniconda3/envs/LatihanCV/Dataset'  

#menentukan ukuran tinggi dan lebar gambar
height = 225
width = 225
dim = (width, height)

#mengumpulkan data citra yang akan dibuka dalam satu array
tampungan_data= [] 
tampungan_label=[]
for path, subdirs, files in os.walk(dirname):
    print(path)
    for name in files:
        img_path = (os.path.join(path, name)) 

        #baca path data
        if (img_path.endswith("jpg")): #dengan file berekstensi jpg
            img = cv2.imread(img_path) #baca gambar
            
            path_parts = path.split('/')
            # Mengambil elemen terakhir dari path_parts sebagai kata terakhir
            last_word = path_parts[-1]

            #preprocessing data / segentasi  boleh dilakukan disini
            status, gambar_haar = haar(img)
            if(status):
                resized=cv2.resize(gambar_haar,dim, interpolation=cv2.INTER_LINEAR) #resize
                tampungan_data.append(resized/255.0) #menumpuk gambar blur pada array tampungan dan di sampling
                tampungan_label.append(last_word)
    X = np.array(tampungan_data) 
    y = np.array(tampungan_label)
# Out:
# C:/Users/Reza/miniconda3/envs/LatihanCV/Dataset
# C:/Users/Reza/miniconda3/envs/LatihanCV/Dataset\aku
# C:/Users/Reza/miniconda3/envs/LatihanCV/Dataset\gibran
# C:/Users/Reza/miniconda3/envs/LatihanCV/Dataset\putin

# %%
import matplotlib.pyplot as plt

list_label=np.unique(y) #mendapatkan label unik
label_dict = {label: idx for idx, label in enumerate(list_label)} #masukkan dalam list
print(label_dict)
label_numerik = [label_dict[s] for s in y] #ubah kedalam numerik
label_numerik_array = np.array(label_numerik)

# Visualisasikan jumlah dalam plot
sns.countplot(x=label_numerik_array)
plt.xlabel('Numeric Labels')
plt.ylabel('Count')
plt.title('Count Plot for Numeric Labels')
plt.show()  

# simpan dalam file npy untuk labeling
np.save('C:/Users/Reza/miniconda3/envs/LatihanCV/weight/label_knn.npy', label_dict)
# Out:
# {'Dataset\\aku': 0, 'Dataset\\gibran': 1, 'Dataset\\putin': 2}

# %%
# Randomly select 6 indices from the data
random_indices = np.random.choice(len(X), 6, replace=False)
# Plot the images
plt.figure(figsize=(12, 6))
for i, idx in enumerate(random_indices):
    plt.subplot(2, 3, i+1)
    plt.imshow(X[idx])
    plt.title("Label: " + str(y[idx]))
plt.tight_layout()
plt.show()

# %%
print(f"awal {X.shape}")

jml_data = X.shape[0]
h = X.shape[1]
w = X.shape[2]
d = X.shape[3]
flatten  = h*w*d
#untuk shape ML itu 1 dimensi jadi X 3 dimensi harus di reshape jadi 1dimensi
X_1d = X.reshape(jml_data, flatten)

print(f"akhir {X_1d.shape}")
# Out:
# awal (10, 225, 225, 3)
# akhir (10, 151875)

# %%
from sklearn.model_selection import train_test_split #library untuk train test split

#melakukan splitting data
X_train, X_test, y_train, y_test = train_test_split(X_1d, label_numerik_array,test_size=0.30, random_state=42, stratify=y) 
#train size adalah persentase data test yang di-split dengan proporsi label yang sama
print("X_train: "+str(X_train.shape))
print("X_test: "+str(X_test.shape))
print("y_train: "+str(y_train.shape))
print("y_test: "+str(y_test.shape))
# Out:
# X_train: (7, 151875)
# X_test: (3, 151875)
# y_train: (7,)
# y_test: (3,)

# %%
from sklearn.model_selection import GridSearchCV,StratifiedKFold #melakukan validasi dengan hasil skor akurasi dengan cross validation 
from sklearn.neighbors import KNeighborsClassifier 

parameters = {'n_neighbors':[1, 3, 5, 7],
             'metric': ['minkowski','euclidean','manhattan']} #masukan parameter yang akan dilakukan 
model = KNeighborsClassifier()
# Create the StratifiedKFold cross-validation method
stratified_kfold = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)


clf = GridSearchCV(model, parameters, verbose=3, cv=stratified_kfold, scoring='accuracy') #panggil gridsearch
clf.fit(X_train,y_train) #train data
best = clf.best_estimator_ #model terbaik
print(clf.best_estimator_) #model terbaik
print(clf.best_score_) #akurasi terbaik
# Out:
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# [CV 1/3] END ...metric=minkowski, n_neighbors=1;, score=0.667 total time=   0.0s
# [CV 2/3] END ...metric=minkowski, n_neighbors=1;, score=1.000 total time=   0.0s
# [CV 3/3] END ...metric=minkowski, n_neighbors=1;, score=1.000 total time=   0.0s
# [CV 1/3] END ...metric=minkowski, n_neighbors=3;, score=0.667 total time=   0.0s
# [CV 2/3] END ...metric=minkowski, n_neighbors=3;, score=0.500 total time=   0.0s
# [CV 3/3] END ...metric=minkowski, n_neighbors=3;, score=1.000 total time=   0.0s
# [CV 1/3] END .....metric=minkowski, n_neighbors=5;, score=nan total time=   0.0s
# [CV 2/3] END ...metric=minkowski, n_neighbors=5;, score=0.500 total time=   0.0s
# [CV 3/3] END ...metric=minkowski, n_neighbors=5;, score=0.500 total time=   0.0s
# [CV 1/3] END .....metric=minkowski, n_neighbors=7;, score=nan total time=   0.0s
# [CV 2/3] END .....metric=minkowski, n_neighbors=7;, score=nan total time=   0.0s
# [CV 3/3] END .....metric=minkowski, n_neighbors=7;, score=nan total time=   0.0s
# C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\model_selection\_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   warnings.warn(
# C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\model_selection\_validation.py:821: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\model_selection\_validation.py", line 810, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\metrics\_scorer.py", line 266, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\metrics\_scorer.py", line 353, in _score
#     y_pred = method_caller(estimator, "predict", X)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\metrics\_scorer.py", line 86, in _cached_call
#     result, _ = _get_response_values(
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\utils\_response.py", line 194, in _get_response_values
#     y_pred = prediction_method(X)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\neighbors\_classification.py", line 254, in predict
#     probabilities = self.predict_proba(X)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\neighbors\_classification.py", line 355, in predict_proba
#     neigh_ind = self.kneighbors(X, return_distance=False)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\neighbors\_base.py", line 808, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples,  but n_samples = 4, n_neighbors = 5
#
#   warnings.warn(
# C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\model_selection\_validation.py:821: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\model_selection\_validation.py", line 810, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\metrics\_scorer.py", line 266, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\metrics\_scorer.py", line 353, in _score
#     y_pred = method_caller(estimator, "predict", X)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\metrics\_scorer.py", line 86, in _cached_call
#     result, _ = _get_response_values(
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\utils\_response.py", line 194, in _get_response_values
#     y_pred = prediction_method(X)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\neighbors\_classification.py", line 254, in predict
#     probabilities = self.predict_proba(X)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\neighbors\_classification.py", line 355, in predict_proba
#     neigh_ind = self.kneighbors(X, return_distance=False)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\neighbors\_base.py", line 808, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples,  but n_samples = 4, n_neighbors = 7
#
#   warnings.warn(
# C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\model_selection\_validation.py:821: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\model_selection\_validation.py", line 810, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\metrics\_scorer.py", line 266, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\metrics\_scorer.py", line 353, in _score
#     y_pred = method_caller(estimator, "predict", X)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\metrics\_scorer.py", line 86, in _cached_call
#     result, _ = _get_response_values(
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\utils\_response.py", line 194, in _get_response_values
#     y_pred = prediction_method(X)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\neighbors\_classification.py", line 254, in predict
#     probabilities = self.predict_proba(X)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\neighbors\_classification.py", line 355, in predict_proba
#     neigh_ind = self.kneighbors(X, return_distance=False)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\neighbors\_base.py", line 808, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples,  but n_samples = 5, n_neighbors = 7
#
#   warnings.warn(
# C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\model_selection\_validation.py:821: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\model_selection\_validation.py", line 810, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\metrics\_scorer.py", line 266, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\metrics\_scorer.py", line 353, in _score
#     y_pred = method_caller(estimator, "predict", X)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\metrics\_scorer.py", line 86, in _cached_call
#     result, _ = _get_response_values(
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\utils\_response.py", line 194, in _get_response_values
#     y_pred = prediction_method(X)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\neighbors\_classification.py", line 254, in predict
#     probabilities = self.predict_proba(X)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\neighbors\_classification.py", line 355, in predict_proba
#     neigh_ind = self.kneighbors(X, return_distance=False)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\neighbors\_base.py", line 808, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples,  but n_samples = 5, n_neighbors = 7
#
#   warnings.warn(
# [CV 1/3] END ...metric=euclidean, n_neighbors=1;, score=0.667 total time=   0.0s
# [CV 2/3] END ...metric=euclidean, n_neighbors=1;, score=1.000 total time=   0.0s
# [CV 3/3] END ...metric=euclidean, n_neighbors=1;, score=1.000 total time=   0.0s
# [CV 1/3] END ...metric=euclidean, n_neighbors=3;, score=0.667 total time=   0.0s
# [CV 2/3] END ...metric=euclidean, n_neighbors=3;, score=0.500 total time=   0.0s
# [CV 3/3] END ...metric=euclidean, n_neighbors=3;, score=1.000 total time=   0.0s
# [CV 1/3] END .....metric=euclidean, n_neighbors=5;, score=nan total time=   0.0s
# [CV 2/3] END ...metric=euclidean, n_neighbors=5;, score=0.500 total time=   0.0s
# [CV 3/3] END ...metric=euclidean, n_neighbors=5;, score=0.500 total time=   0.0s
# [CV 1/3] END .....metric=euclidean, n_neighbors=7;, score=nan total time=   0.0s
# [CV 2/3] END .....metric=euclidean, n_neighbors=7;, score=nan total time=   0.0s
# [CV 3/3] END .....metric=euclidean, n_neighbors=7;, score=nan total time=   0.0s
# [CV 1/3] END ...metric=manhattan, n_neighbors=1;, score=0.667 total time=   0.0s
# [CV 2/3] END ...metric=manhattan, n_neighbors=1;, score=1.000 total time=   0.0s
# [CV 3/3] END ...metric=manhattan, n_neighbors=1;, score=1.000 total time=   0.0s
# [CV 1/3] END ...metric=manhattan, n_neighbors=3;, score=0.667 total time=   0.0s
# [CV 2/3] END ...metric=manhattan, n_neighbors=3;, score=0.500 total time=   0.0s
# [CV 3/3] END ...metric=manhattan, n_neighbors=3;, score=1.000 total time=   0.0s
# [CV 1/3] END ...metric=manhattan, n_neighbors=5;, score=0.333 total time=   0.0s
# [CV 2/3] END ...metric=manhattan, n_neighbors=5;, score=0.500 total time=   0.0s
# [CV 3/3] END ...metric=manhattan, n_neighbors=5;, score=0.500 total time=   0.0s
# [CV 1/3] END ...metric=manhattan, n_neighbors=7;, score=0.333 total time=   0.0s
# [CV 2/3] END ...metric=manhattan, n_neighbors=7;, score=0.500 total time=   0.0s
# [CV 3/3] END ...metric=manhattan, n_neighbors=7;, score=0.500 total time=   0.0s
# KNeighborsClassifier(n_neighbors=1)
# 0.8888888888888888
# C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\model_selection\_validation.py:821: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\model_selection\_validation.py", line 810, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\metrics\_scorer.py", line 266, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\metrics\_scorer.py", line 353, in _score
#     y_pred = method_caller(estimator, "predict", X)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\metrics\_scorer.py", line 86, in _cached_call
#     result, _ = _get_response_values(
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\utils\_response.py", line 194, in _get_response_values
#     y_pred = prediction_method(X)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\neighbors\_classification.py", line 266, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\neighbors\_base.py", line 808, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples,  but n_samples = 4, n_neighbors = 5
#
#   warnings.warn(
# C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\model_selection\_validation.py:821: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\model_selection\_validation.py", line 810, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\metrics\_scorer.py", line 266, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\metrics\_scorer.py", line 353, in _score
#     y_pred = method_caller(estimator, "predict", X)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\metrics\_scorer.py", line 86, in _cached_call
#     result, _ = _get_response_values(
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\utils\_response.py", line 194, in _get_response_values
#     y_pred = prediction_method(X)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\neighbors\_classification.py", line 266, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\neighbors\_base.py", line 808, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples,  but n_samples = 4, n_neighbors = 7
#
#   warnings.warn(
# C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\model_selection\_validation.py:821: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\model_selection\_validation.py", line 810, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\metrics\_scorer.py", line 266, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\metrics\_scorer.py", line 353, in _score
#     y_pred = method_caller(estimator, "predict", X)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\metrics\_scorer.py", line 86, in _cached_call
#     result, _ = _get_response_values(
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\utils\_response.py", line 194, in _get_response_values
#     y_pred = prediction_method(X)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\neighbors\_classification.py", line 266, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\neighbors\_base.py", line 808, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples,  but n_samples = 5, n_neighbors = 7
#
#   warnings.warn(
# C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\model_selection\_validation.py:821: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\model_selection\_validation.py", line 810, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\metrics\_scorer.py", line 266, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\metrics\_scorer.py", line 353, in _score
#     y_pred = method_caller(estimator, "predict", X)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\metrics\_scorer.py", line 86, in _cached_call
#     result, _ = _get_response_values(
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\utils\_response.py", line 194, in _get_response_values
#     y_pred = prediction_method(X)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\neighbors\_classification.py", line 266, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\neighbors\_base.py", line 808, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples,  but n_samples = 5, n_neighbors = 7
#
#   warnings.warn(
# C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\model_selection\_search.py:979: UserWarning: One or more of the test scores are non-finite: [0.88888889 0.72222222        nan        nan 0.88888889 0.72222222
#         nan        nan 0.88888889 0.72222222 0.44444444 0.44444444]
#   warnings.warn(

# %%
X_train, X_test, y_train, y_test = train_test_split(X_1d, label_numerik_array,test_size=0.30, random_state=42, stratify=y)

# %%
# Visualize the metric distances for each label separately with different marker shapes
plt.figure(figsize=(8, 6))

# Dictionary to map label to marker shape
marker_dict = {0: 's', 1: '^', 2: 'o'}
# Fit the KNeighborsClassifier model to the training data
model = KNeighborsClassifier()
model.fit(X_train, y_train)
# Get the distances to the k nearest neighbors for each data point
distances, _ = model.kneighbors(X_train)
for label in np.unique(y_train):
    # Get the indices of data points belonging to the current label
    label_indices = np.where(y_train == label)[0]
    
    # Get the distances to the k nearest neighbors for data points of the current label
    label_distances = np.mean(distances[label_indices], axis=1)
    
    # Plot the distances for the current label with the corresponding marker shape
    plt.scatter(X_train[label_indices, 0], X_train[label_indices, 1], c=label_distances, cmap='plasma', edgecolors='k', label=f"Class {label}", marker=marker_dict[label])

plt.colorbar(label='Average Distance to k Nearest Neighbors')
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.title("KNN - Metric Distance Visualization for Each Label")
plt.legend()
plt.show()

# %%
y_pred = best.predict(X_test) #predict untuk memprediksi data test

# %%
from sklearn.metrics import confusion_matrix

# Create a confusion matrix
cm = confusion_matrix(y_test, y_pred)
# Plot the confusion matrix
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.title("Confusion Matrix")
plt.show()

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred)) #evaluasi hasil
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00         1
#            2       1.00      1.00      1.00         1
#
#     accuracy                           1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3

# %%
import matplotlib.pyplot as plt
import cv2
import os
import os.path
import numpy as np

url= 'C:/Users/Reza/miniconda3/envs/LatihanCV/Dataset/aku/aku1.jpg'
img=cv2.imread(url)
plt.figure()
plt.title("Data Test")
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()

#pastikan langkah preprocessing yang dilakukan sama dengan data train
status,haarnya=haar(img)
convert = haarnya/255.0
img_resize = cv2.resize(convert,(225,225))
#tampilkan hasil
plt.figure()
plt.title("Hasil preprocessing")
plt.imshow(img_resize)
plt.show()

test=[img_resize.flatten()] #makukan ke list
print(f"ukuran gambar test {img_resize.flatten().shape}") #sama dengan input shape

# Mengecek hasil klasifikasi pada salah satu dataset
probability=best.predict_proba(test)
print(f"nilai probabilitas {probability}") #tampilkan nilai probabilitas tiap kelas



for ind,val in enumerate(label_dict): #mendapatkan nama kelas dan hasil akurasi
    print(f'{val} = {probability[0][ind]*100}%')
    
    
hasil = np.argmax(probability, axis=-1) #mendapatkan kelas dari probabilitas terbaik
key_found = [key for key, value in label_dict.items() if value == hasil] #dapatkan namanya
print(f"prediksinya: {key_found}")
print(f"The predicted image is : {str(hasil)} -> {key_found}")
# Out:
# ukuran gambar test (151875,)
# nilai probabilitas [[1. 0. 0.]]
# Dataset\aku = 100.0%
# Dataset\gibran = 0.0%
# Dataset\putin = 0.0%
# prediksinya: ['Dataset\\aku']
# The predicted image is : [0] -> ['Dataset\\aku']

# %%
import numpy as np
import seaborn as sns
# buat NumPy array
X_train = np.array([
    [1, 2],
    [3, 4],
    [5, 6],
])

# Save the NumPy array to a `.npy` file
np.save('C:\\Users\\Reza\\miniconda3\\envs\\LatihanCV\\weight\\X_train.npy', X_train)

# %%
pickle.dump(best, open('C:\\Users\\Reza\\miniconda3\\envs\\LatihanCV\\weight\\model_haar_knn_optimasi.pkl', 'wb')) #simpan dalam file.pkl

# %%
import cv2
import os
import os.path
import numpy as np
from time import sleep
import pickle

def read_model(filename, path=""):
    with open(os.path.join(path, filename), 'rb') as in_name:
        model = pickle.load(in_name)
        return model
color = (255, 0, 0)
cap = cv2.VideoCapture(0) # 0 jika kamera
model = read_model("C:\\Users\\Reza\\miniconda3\\envs\\LatihanCV\\weight\\model_haar_knn_optimasi.pkl", path="") #load model
label_dict = np.load('C:\\Users\\Reza\\miniconda3\\envs\\LatihanCV\\weight\\label_knn.npy', allow_pickle=True).item() #load label


while (cap.isOpened()):
    ret , frame = cap.read() #baca vidio dengan looping gambar
    if ret:
        face_roi = []# Load Haar Cascade classifier for face detection
        face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
        # Convert the image to grayscale (required for face detection)
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

        # Detect faces in the image using the face_cascade
        faces = face_cascade.detectMultiScale(gray, scaleFactor=1.5, minNeighbors=5)
        # Draw bounding boxes around the detected faces and display the image
        for (x, y, w, h) in faces:
            # Draw a rectangle around the detected face
            face_roi = frame[y:y+h, x:x+w]
            cv2.rectangle(frame, (x-5, y-5), (x + w+5, y + h+5), (0, 255, 0), 4)#beri rectangle dan beri overlap sebesar 5
            convert = face_roi/255.0 #preprocessing
            muka = cv2.resize(convert, (225,225), interpolation = cv2.INTER_AREA)#wajib sama dengan citra inputan trainer
            cv2.imshow("Detect",muka)
            gambar_flat=[muka.flatten()] #jadikan 1 dimensi
            prediksi= model.predict(gambar_flat) #prediksi
            key_found = [key for key, value in label_dict.items() if value == prediksi] #dapatkan namanya
            cv2.putText(frame, f"Deteksi : {key_found[0]}", (20, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255),2)
            cv2.imshow("Detect",muka)
        cv2.imshow("Video Original" , frame)
    else:
        print('no video')
        cap.set(cv2.CAP_PROP_POS_FRAMES, 0)
        continue

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
    
cap.release()
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 47
#      44         cap.set(cv2.CAP_PROP_POS_FRAMES, 0)
#      45         continue
# ---> 47     if cv2.waitKey(1) & 0xFF == ord('q'):
#      48         break
#      50 cap.release()
#
# KeyboardInterrupt:

# %%
def haar(img):
    face_roi = []
    status = False  

    # Load Haar Cascade classifier for face detection
    face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')  

    # Convert the image to grayscale (required for face detection)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # Detect faces in the image using the face_cascade
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.5, minNeighbors=5)  

    # Draw bounding boxes around the detected faces and display the image
    for (x, y, w, h) in faces:
        # Draw a rectangle around the detected face
        face_roi = img[y:y+h, x:x+w]
        status = True
    return status,face_roi

# %%
# Loading the image
img = cv2.imread('C:\\Users\\Reza\\miniconda3\\envs\\LatihanCV\\Dataset\\aku\\aku4.jpg')
status,haarnya=haar(img)  

# Applying SIFT detector
sift = cv2.SIFT_create(500)
kpts, des = sift.detectAndCompute(haarnya, None)  

# Marking the keypoint on the image using circles
img=cv2.drawKeypoints(haarnya, kpts , haarnya ,flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
print(f" jumlah keypoint terbentuk {len(kpts)}")
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
# Out:
#  jumlah keypoint terbentuk 500

# %%
#kmeans works only on float, so convert integers to float
descriptors_float = des.astype(float)  

# Perform k-means clustering and vector quantization

from scipy.cluster.vq import kmeans, vq
k = 200  #dari total 500 diambil hanya 200
voc, variance = kmeans(obs=descriptors_float, k_or_guess=k, iter=5) 


# Calculate the histogram of features and represent them as vector
#vq Assigns codes from a code book to observations.
im_features = np.zeros((1, k), "float32")
for i in range(1):
    words, distance = vq(des,voc)
    for w in words:
        im_features[i][w] += 1
print(im_features.shape)
print(im_features)
# Out:
# (1, 200)
# [[ 3.  1.  2.  1.  1.  1.  1.  1.  1.  2.  3.  3.  1.  4.  2.  5.  3.  7.
#    1.  1.  2.  3.  1.  3.  1.  2.  1.  2.  1.  4.  4.  3.  2.  2.  2.  1.
#    2.  3. 10.  2.  8.  4.  3.  3.  3.  1.  2.  2.  1.  4.  1.  6.  1.  4.
#    1.  3.  3.  5.  4.  2.  2.  4.  1.  1.  1.  2.  3.  1.  4.  2.  2.  7.
#    4.  1.  6. 10.  1.  4.  1.  2.  1.  3.  2.  1.  1.  3.  1.  1.  2.  3.
#    2.  5.  2.  2.  4.  3.  3.  6.  1.  1.  2.  2.  3.  1.  1.  3.  1.  1.
#    3.  1.  3.  3.  1.  2.  2.  4.  2.  2.  3.  3.  1.  3.  1.  1.  5.  3.
#    2.  3.  2.  4.  4.  2.  1.  2.  1.  2.  7.  2.  1.  1.  3.  2.  3.  2.
#    2.  2.  4.  3.  3.  1.  2.  5.  1.  1.  5.  1.  1.  1.  2.  4.  5.  2.
#    1.  1.  2.  3.  1.  3.  9.  3.  4.  4.  2.  1.  1.  3.  3.  1.  3.  1.
#    2.  2.  1.  7.  5.  1.  6.  2.  1.  2.  1.  1.  2.  3.  2.  1.  4.  1.
#    1.  1.]]

# %%
#menentukan direktori/folder data citra yang akan dibuka
dirname = 'C:/Users/Reza/miniconda3/envs/LatihanCV/Dataset'  

#menentukan ukuran tinggi dan lebar gambar
height = 225
width = 225
dim = (width, height)

#BRISK is a good replacement to SIFT. ORB also works but didn;t work well for this example  
sift = cv2.SIFT_create()
#mengumpulkan data citra yang akan dibuka dalam satu array
tampungan_data = [] 
tampungan_label = []
for path, subdirs, files in os.walk(dirname):
    print(path)
    for name in files:
        img_path = (os.path.join(path, name))  #baca path data
        if (img_path.endswith("jpg")): #dengan file berekstensi jpg
            img = cv2.imread(img_path) #baca gambar
            status, haarnya = haar(img)
            if(status):
                resized=cv2.resize(haarnya,dim, interpolation=cv2.INTER_LINEAR) #resize
                kpts, des = sift.detectAndCompute(resized, None)
                tampungan_data.append(des)
                
                path_parts = path.split('/')
                # Mengambil elemen terakhir dari path_parts sebagai kata terakhir
                last_word = path_parts[-1]
                #preprocessing data / segentasi  boleh dilakukan disini
                tampungan_label.append(last_word)
    X = np.array(tampungan_data, dtype=object) 
    y = np.array(tampungan_label)
# Out:
# C:/Users/Reza/miniconda3/envs/LatihanCV/Dataset
# C:/Users/Reza/miniconda3/envs/LatihanCV/Dataset\aku
# C:/Users/Reza/miniconda3/envs/LatihanCV/Dataset\gibran
# C:/Users/Reza/miniconda3/envs/LatihanCV/Dataset\putin

# %%
descriptors = None
for descriptor in X:
    if descriptors is None:
        descriptors = descriptor
    else:
        descriptors = np.vstack((descriptors, descriptor)) #gunakan untuk menggabungkan deskriptor menjadi satu tumpukan

#kmeans works only on float, so convert integers to float
descriptors_float = descriptors.astype(float)  
# Perform k-means clustering and vector quantization
from scipy.cluster.vq import kmeans, vq

k = 200  #k means with 100 clusters gives lower accuracy for the aeroplane example
voc, variance = kmeans(obs=descriptors_float, k_or_guess=k, iter=5) 

# Calculate the histogram of features and represent them as vector
# vq Assigns codes from a code book to observations.
im_features = np.zeros((len(y), k), "float32")
for i in range(len(y)):
    words, distance = vq(X[i],voc)
    for w in words:
        im_features[i][w] += 1
print(im_features.shape)
# Out:
# (10, 200)

# %%
list_label=np.unique(y) #mendapatkan label unik
label_dict = {label: idx for idx, label in enumerate(list_label)} #masukkan dalam list
print(f"{label_dict} jumlah data: {len(y)}")

label_numerik = [label_dict[s] for s in y] #ubah kedalam numerik
label_numerik_array = np.array(label_numerik)

# Visualisasikan dalam jumlah dalam plot
sns.countplot(x=label_numerik_array)
plt.xlabel('Numeric Labels')
plt.ylabel('Count')
plt.title('Count Plot for Numeric Labels')
plt.show()  

# simpan dalam file npy untuk labeling
np.save('C:\\Users\\Reza\\miniconda3\\envs\\LatihanCV\\weight\\label_knn.npy', label_dict)
# Out:
# {'Dataset\\aku': 0, 'Dataset\\gibran': 1, 'Dataset\\putin': 2} jumlah data: 10

# %%
from sklearn.model_selection import train_test_split #library untuk train test split

#melakukan splitting data
X_train, X_test, y_train, y_test = train_test_split(im_features, label_numerik_array,test_size=0.25, stratify=label_numerik_array) 
#train size adalah persentase data test yang di-split dengan proporsi label yang sama

print("X_train: "+str(X_train.shape))
print("X_test: "+str(X_test.shape))
print("y_train: "+str(y_train.shape))
print("y_test: "+str(y_test.shape))
# Out:
# X_train: (7, 200)
# X_test: (3, 200)
# y_train: (7,)
# y_test: (3,)

# %%
from sklearn.model_selection import GridSearchCV,StratifiedKFold #melakukan validasi dengan hasil skor akurasi dengan cross validation
from sklearn.neighbors import KNeighborsClassifier

parameters = {'n_neighbors':[1, 3, 5, 7],
             'metric': ['minkowski','euclidean','manhattan']} #masukan parameter yang akan dilakukan
model = KNeighborsClassifier()

# Create the StratifiedKFold cross-validation method
stratified_kfold = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)


clf = GridSearchCV(model, parameters, verbose=3, cv=stratified_kfold, scoring='accuracy') #panggil gridsearch
clf.fit(X_train,y_train) #train data
best = clf.best_estimator_ #model terbaik
print(clf.best_estimator_) #model terbaik
print(clf.best_score_) #akurasi terbaik
# Out:
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# [CV 1/3] END ...metric=minkowski, n_neighbors=1;, score=0.667 total time=   0.0s
# [CV 2/3] END ...metric=minkowski, n_neighbors=1;, score=1.000 total time=   0.0s
# [CV 3/3] END ...metric=minkowski, n_neighbors=1;, score=1.000 total time=   0.0s
# [CV 1/3] END ...metric=minkowski, n_neighbors=3;, score=0.333 total time=   0.0s
# [CV 2/3] END ...metric=minkowski, n_neighbors=3;, score=1.000 total time=   0.0s
# [CV 3/3] END ...metric=minkowski, n_neighbors=3;, score=1.000 total time=   0.0s
# [CV 1/3] END .....metric=minkowski, n_neighbors=5;, score=nan total time=   0.0s
# [CV 2/3] END ...metric=minkowski, n_neighbors=5;, score=0.500 total time=   0.0s
# [CV 3/3] END ...metric=minkowski, n_neighbors=5;, score=0.500 total time=   0.0s
# [CV 1/3] END .....metric=minkowski, n_neighbors=7;, score=nan total time=   0.0s
# [CV 2/3] END .....metric=minkowski, n_neighbors=7;, score=nan total time=   0.0s
# [CV 3/3] END .....metric=minkowski, n_neighbors=7;, score=nan total time=   0.0s
# [CV 1/3] END ...metric=euclidean, n_neighbors=1;, score=0.667 total time=   0.0s
# [CV 2/3] END ...metric=euclidean, n_neighbors=1;, score=1.000 total time=   0.0s
# [CV 3/3] END ...metric=euclidean, n_neighbors=1;, score=1.000 total time=   0.0s
# [CV 1/3] END ...metric=euclidean, n_neighbors=3;, score=0.333 total time=   0.0s
# [CV 2/3] END ...metric=euclidean, n_neighbors=3;, score=1.000 total time=   0.0s
# [CV 3/3] END ...metric=euclidean, n_neighbors=3;, score=1.000 total time=   0.0s
# [CV 1/3] END .....metric=euclidean, n_neighbors=5;, score=nan total time=   0.0s
# [CV 2/3] END ...metric=euclidean, n_neighbors=5;, score=0.500 total time=   0.0s
# [CV 3/3] END ...metric=euclidean, n_neighbors=5;, score=0.500 total time=   0.0s
# [CV 1/3] END .....metric=euclidean, n_neighbors=7;, score=nan total time=   0.0s
# [CV 2/3] END .....metric=euclidean, n_neighbors=7;, score=nan total time=   0.0s
# [CV 3/3] END .....metric=euclidean, n_neighbors=7;, score=nan total time=   0.0s
# C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\model_selection\_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   warnings.warn(
# C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\model_selection\_validation.py:821: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\model_selection\_validation.py", line 810, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\metrics\_scorer.py", line 266, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\metrics\_scorer.py", line 353, in _score
#     y_pred = method_caller(estimator, "predict", X)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\metrics\_scorer.py", line 86, in _cached_call
#     result, _ = _get_response_values(
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\utils\_response.py", line 194, in _get_response_values
#     y_pred = prediction_method(X)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\neighbors\_classification.py", line 254, in predict
#     probabilities = self.predict_proba(X)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\neighbors\_classification.py", line 355, in predict_proba
#     neigh_ind = self.kneighbors(X, return_distance=False)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\neighbors\_base.py", line 808, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples,  but n_samples = 4, n_neighbors = 5
#
#   warnings.warn(
# C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\model_selection\_validation.py:821: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\model_selection\_validation.py", line 810, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\metrics\_scorer.py", line 266, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\metrics\_scorer.py", line 353, in _score
#     y_pred = method_caller(estimator, "predict", X)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\metrics\_scorer.py", line 86, in _cached_call
#     result, _ = _get_response_values(
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\utils\_response.py", line 194, in _get_response_values
#     y_pred = prediction_method(X)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\neighbors\_classification.py", line 254, in predict
#     probabilities = self.predict_proba(X)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\neighbors\_classification.py", line 355, in predict_proba
#     neigh_ind = self.kneighbors(X, return_distance=False)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\neighbors\_base.py", line 808, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples,  but n_samples = 4, n_neighbors = 7
#
#   warnings.warn(
# C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\model_selection\_validation.py:821: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\model_selection\_validation.py", line 810, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\metrics\_scorer.py", line 266, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\metrics\_scorer.py", line 353, in _score
#     y_pred = method_caller(estimator, "predict", X)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\metrics\_scorer.py", line 86, in _cached_call
#     result, _ = _get_response_values(
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\utils\_response.py", line 194, in _get_response_values
#     y_pred = prediction_method(X)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\neighbors\_classification.py", line 254, in predict
#     probabilities = self.predict_proba(X)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\neighbors\_classification.py", line 355, in predict_proba
#     neigh_ind = self.kneighbors(X, return_distance=False)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\neighbors\_base.py", line 808, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples,  but n_samples = 5, n_neighbors = 7
#
#   warnings.warn(
# C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\model_selection\_validation.py:821: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\model_selection\_validation.py", line 810, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\metrics\_scorer.py", line 266, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\metrics\_scorer.py", line 353, in _score
#     y_pred = method_caller(estimator, "predict", X)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\metrics\_scorer.py", line 86, in _cached_call
#     result, _ = _get_response_values(
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\utils\_response.py", line 194, in _get_response_values
#     y_pred = prediction_method(X)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\neighbors\_classification.py", line 254, in predict
#     probabilities = self.predict_proba(X)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\neighbors\_classification.py", line 355, in predict_proba
#     neigh_ind = self.kneighbors(X, return_distance=False)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\neighbors\_base.py", line 808, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples,  but n_samples = 5, n_neighbors = 7
#
#   warnings.warn(
# C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\model_selection\_validation.py:821: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\model_selection\_validation.py", line 810, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\metrics\_scorer.py", line 266, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\metrics\_scorer.py", line 353, in _score
#     y_pred = method_caller(estimator, "predict", X)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\metrics\_scorer.py", line 86, in _cached_call
#     result, _ = _get_response_values(
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\utils\_response.py", line 194, in _get_response_values
#     y_pred = prediction_method(X)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\neighbors\_classification.py", line 266, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\neighbors\_base.py", line 808, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples,  but n_samples = 4, n_neighbors = 5
#
#   warnings.warn(
# C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\model_selection\_validation.py:821: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\model_selection\_validation.py", line 810, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\metrics\_scorer.py", line 266, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\metrics\_scorer.py", line 353, in _score
#     y_pred = method_caller(estimator, "predict", X)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\metrics\_scorer.py", line 86, in _cached_call
#     result, _ = _get_response_values(
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\utils\_response.py", line 194, in _get_response_values
#     y_pred = prediction_method(X)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\neighbors\_classification.py", line 266, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\neighbors\_base.py", line 808, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples,  but n_samples = 4, n_neighbors = 7
#
#   warnings.warn(
# C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\model_selection\_validation.py:821: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\model_selection\_validation.py", line 810, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\metrics\_scorer.py", line 266, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\metrics\_scorer.py", line 353, in _score
#     y_pred = method_caller(estimator, "predict", X)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\metrics\_scorer.py", line 86, in _cached_call
#     result, _ = _get_response_values(
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\utils\_response.py", line 194, in _get_response_values
#     y_pred = prediction_method(X)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\neighbors\_classification.py", line 266, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\neighbors\_base.py", line 808, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples,  but n_samples = 5, n_neighbors = 7
#
#   warnings.warn(
# C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\model_selection\_validation.py:821: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\model_selection\_validation.py", line 810, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\metrics\_scorer.py", line 266, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\metrics\_scorer.py", line 353, in _score
#     y_pred = method_caller(estimator, "predict", X)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\metrics\_scorer.py", line 86, in _cached_call
#     result, _ = _get_response_values(
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\utils\_response.py", line 194, in _get_response_values
#     y_pred = prediction_method(X)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\neighbors\_classification.py", line 266, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#   File "C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\neighbors\_base.py", line 808, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples,  but n_samples = 5, n_neighbors = 7
#
#   warnings.warn(
# [CV 1/3] END ...metric=manhattan, n_neighbors=1;, score=0.333 total time=   0.2s
# [CV 2/3] END ...metric=manhattan, n_neighbors=1;, score=1.000 total time=   0.0s
# [CV 3/3] END ...metric=manhattan, n_neighbors=1;, score=1.000 total time=   0.0s
# [CV 1/3] END ...metric=manhattan, n_neighbors=3;, score=0.333 total time=   0.0s
# [CV 2/3] END ...metric=manhattan, n_neighbors=3;, score=1.000 total time=   0.0s
# [CV 3/3] END ...metric=manhattan, n_neighbors=3;, score=1.000 total time=   0.0s
# [CV 1/3] END ...metric=manhattan, n_neighbors=5;, score=0.333 total time=   0.0s
# [CV 2/3] END ...metric=manhattan, n_neighbors=5;, score=0.500 total time=   0.0s
# [CV 3/3] END ...metric=manhattan, n_neighbors=5;, score=0.500 total time=   0.0s
# [CV 1/3] END ...metric=manhattan, n_neighbors=7;, score=0.333 total time=   0.0s
# [CV 2/3] END ...metric=manhattan, n_neighbors=7;, score=0.500 total time=   0.0s
# [CV 3/3] END ...metric=manhattan, n_neighbors=7;, score=0.500 total time=   0.0s
# KNeighborsClassifier(n_neighbors=1)
# 0.8888888888888888
# C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\model_selection\_search.py:979: UserWarning: One or more of the test scores are non-finite: [0.88888889 0.77777778        nan        nan 0.88888889 0.77777778
#         nan        nan 0.77777778 0.77777778 0.44444444 0.44444444]
#   warnings.warn(

# %%
# Visualize the metric distances for each label separately with different marker shapes
plt.figure(figsize=(8, 6))
distances, _ = best.kneighbors(X_train)

# Dictionary to map label to marker shape
marker_dict = {0: 's', 1: '^', 2: 'o'}

for label in np.unique(y_train):
    # Get the indices of data points belonging to the current label
    label_indices = np.where(y_train == label)[0]
    
    # Get the distances to the k nearest neighbors for data points of the current label
    label_distances = np.mean(distances[label_indices], axis=1)
    
    # Plot the distances for the current label with the corresponding marker shape
    plt.scatter(X_train[label_indices, 0], X_train[label_indices, 1], c=label_distances, cmap='plasma', edgecolors='k', label=f"Class {label}", marker=marker_dict[label])

plt.colorbar(label='Average Distance to k Nearest Neighbors')
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.title("KNN - Metric Distance Visualization for Each Label")
plt.legend()
plt.show()

# %%
y_pred = best.predict(X_test) #predict untuk memprediksi data test

# %%
# Create a confusion matrix
cm = confusion_matrix(y_test, y_pred)
# Plot the confusion matrix
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.title("Confusion Matrix")
plt.show()
print(classification_report(y_test, y_pred)) #evaluasi hasil
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       0.00      0.00      0.00         1
#            2       0.50      1.00      0.67         1
#
#     accuracy                           0.67         3
#    macro avg       0.50      0.67      0.56         3
# weighted avg       0.50      0.67      0.56         3
# C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Reza\miniconda3\envs\LatihanCV\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
import matplotlib.pyplot as plt
import cv2
import os
import os.path
import numpy as np  


"""SIFT ADA DI SINI"""


url= 'C:\\Users\\Reza\\miniconda3\\envs\\LatihanCV\\Dataset\\aku\\aku4.jpg'
img=cv2.imread(url)
plt.figure()
plt.title("Data Test")
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()

#pastikan langkah preprocessing yang dilakukan sama dengan data train
status,haarnya=haar(img)
img_resize = cv2.resize(haarnya,(225,225))
#tampilkan hasil
plt.figure()
plt.title("Hasil Haar")
plt.imshow(cv2.cvtColor(img_resize, cv2.COLOR_BGR2RGB))
plt.show()


plt.figure()
plt.title("Hasil Sift")
# sift = cv2.SIFT_create()
sift = cv2.SIFT_create(nfeatures=500, nOctaveLayers=9, contrastThreshold=0.03, edgeThreshold=10, sigma=1.6)
kpts, des = sift.detectAndCompute(img_resize, None)
# Marking the keypoint on the image using circles
img=cv2.drawKeypoints(img_resize, kpts , img_resize ,flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
print(f" jumlah keypoint terbentuk {len(kpts)}")
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()


# bovw
#kmeans works only on float, so convert integers to float
descriptors_float = des.astype(float)  
# Perform k-means clustering and vector quantization
from scipy.cluster.vq import kmeans, vq
k = 200  #dari total 500 diambil hanya 200
voc, variance = kmeans(obs=descriptors_float, k_or_guess=k, iter=5) 
# Calculate the histogram of features and represent them as vector
#vq Assigns codes from a code book to observations.
im_features = np.zeros((1, k), "float32")
for i in range(1):
    words, distance = vq(des,voc)
    for w in words:
        im_features[i][w] += 1
print(im_features.shape)

print(f"ukuran data test {im_features.shape}") #sama dengan input shape

# Mengecek hasil klasifikasi pada salah satu dataset
probability=best.predict_proba(im_features)
print(f"nilai probabilitas {probability}") #tampilkan nilai probabilitas tiap kelas



for ind,val in enumerate(label_dict): #mendapatkan nama kelas dan hasil akurasi
    print(f'{val} = {probability[0][ind]*100}%')
    
    
hasil = np.argmax(probability, axis=-1) #mendapatkan kelas dari probabilitas terbaik
key_found = [key for key, value in label_dict.items() if value == hasil] #dapatkan namanya
print(f"prediksinya: {key_found}")
print(f"The predicted image is : {str(hasil)} -> {key_found}")
# Out:
#  jumlah keypoint terbentuk 500
# (1, 200)
# ukuran data test (1, 200)
# nilai probabilitas [[1. 0. 0.]]
# Dataset\aku = 100.0%
# Dataset\gibran = 0.0%
# Dataset\putin = 0.0%
# prediksinya: ['Dataset\\aku']
# The predicted image is : [0] -> ['Dataset\\aku']

# %%
import pickle
pickle.dump(best, open('C:\\Users\\Reza\\miniconda3\\envs\\LatihanCV\\weight\\model_haar_sift_knn_optimasi.pkl', 'wb')) #simpan dalam file.pkl

# %%
import cv2
import os
import os.path
import numpy as np
from time import sleep
import pickle

def read_model(filename, path=""):
    with open(os.path.join(path, filename), 'rb') as in_name:
        model = pickle.load(in_name)
        return model
    

color = (255, 0, 0)
cap = cv2.VideoCapture(0) # 0 jika kamera
model = read_model("C:/Users/Reza/miniconda3/envs/LatihanCV/weight/model_haar_sift_knn_optimasi.pkl", path="") #load model
label_dict = np.load('C:/Users/Reza/miniconda3/envs/LatihanCV/weight/label_knn.npy', allow_pickle=True).item() #load label


while (cap.isOpened()):
    ret , frame = cap.read() #baca vidio dengan looping gambar
    if ret:
        face_roi = []# Load Haar Cascade classifier for face detection
        face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
        # Convert the image to grayscale (required for face detection)
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

        # Detect faces in the image using the face_cascade
        faces = face_cascade.detectMultiScale(gray, scaleFactor=1.5, minNeighbors=5)
        # Draw bounding boxes around the detected faces and display the image
        for (x, y, w, h) in faces:
            # Draw a rectangle around the detected face
            face_roi = frame[y:y+h, x:x+w]
            cv2.rectangle(frame, (x-5, y-5), (x + w+5, y + h+5), (0, 255, 0), 4)#beri rectangle dan beri overlap sebesar 5
            muka = cv2.resize(face_roi, (225,225), interpolation = cv2.INTER_AREA)#wajib sama dengan citra inputan trainer
            #sift
            sift = cv2.SIFT_create(nfeatures=500, nOctaveLayers=9, contrastThreshold=0.03, edgeThreshold=10, sigma=1.6)
            kpts, des = sift.detectAndCompute(muka, None)
            print(f" jumlah keypoint terbentuk {len(kpts)}")
            if(len(kpts) >= 200): #karna sistem akan akan menggunakan shape 200 minimal
                cv2.imshow("Haar",muka)
                # Marking the keypoint on the image using circles
                img=cv2.drawKeypoints(muka, kpts , muka ,flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
                # BOVW
                #kmeans works only on float, so convert integers to float
                descriptors_float = des.astype(float)  
                # Perform k-means clustering and vector quantization
                from scipy.cluster.vq import kmeans, vq
                k = 200  #dari total 500 diambil hanya 200
                voc, variance = kmeans(obs=descriptors_float, k_or_guess=k, iter=5) 
                # Calculate the histogram of features and represent them as vector
                #vq Assigns codes from a code book to observations.
                im_features = np.zeros((1, k), "float32")
                for i in range(1):
                    words, distance = vq(des,voc)
                    for w in words:
                        im_features[i][w] += 1
                
                cv2.imshow("Sift",img)
                prediksi= model.predict(im_features) #prediksi
                key_found = [key for key, value in label_dict.items() if value == prediksi] #dapatkan namanya
                cv2.putText(frame, f"Deteksi : {key_found[0]}", (20, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255),2)
        cv2.imshow("Video Original" , frame)
    else:
        print('no video')
        cap.set(cv2.CAP_PROP_POS_FRAMES, 0)
        continue

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
    
cap.release()
cv2.destroyAllWindows()
cv2.waitKey(1)
# Out:
#  jumlah keypoint terbentuk 326
#  jumlah keypoint terbentuk 326
#  jumlah keypoint terbentuk 300
#  jumlah keypoint terbentuk 314
#  jumlah keypoint terbentuk 323
#  jumlah keypoint terbentuk 306
#  jumlah keypoint terbentuk 301
#  jumlah keypoint terbentuk 306
#  jumlah keypoint terbentuk 309
#  jumlah keypoint terbentuk 298
#  jumlah keypoint terbentuk 303
#  jumlah keypoint terbentuk 354
#  jumlah keypoint terbentuk 321
#  jumlah keypoint terbentuk 336
#  jumlah keypoint terbentuk 336
#  jumlah keypoint terbentuk 283
#  jumlah keypoint terbentuk 300
#  jumlah keypoint terbentuk 323
#  jumlah keypoint terbentuk 323
#  jumlah keypoint terbentuk 383
#  jumlah keypoint terbentuk 383
#  jumlah keypoint terbentuk 318
#  jumlah keypoint terbentuk 301
#  jumlah keypoint terbentuk 324
#  jumlah keypoint terbentuk 309
#  jumlah keypoint terbentuk 294
#  jumlah keypoint terbentuk 285
#  jumlah keypoint terbentuk 271
#  jumlah keypoint terbentuk 244
#  jumlah keypoint terbentuk 331
#  jumlah keypoint terbentuk 282
#  jumlah keypoint terbentuk 272
#  jumlah keypoint terbentuk 272
#  jumlah keypoint terbentuk 253
#  jumlah keypoint terbentuk 239
#  jumlah keypoint terbentuk 254
#  jumlah keypoint terbentuk 285
#  jumlah keypoint terbentuk 260
#  jumlah keypoint terbentuk 270
#  jumlah keypoint terbentuk 230
#  jumlah keypoint terbentuk 209
#  jumlah keypoint terbentuk 240
#  jumlah keypoint terbentuk 304
#  jumlah keypoint terbentuk 199
#  jumlah keypoint terbentuk 223
#  jumlah keypoint terbentuk 305
#  jumlah keypoint terbentuk 213
#  jumlah keypoint terbentuk 213
#  jumlah keypoint terbentuk 215
#  jumlah keypoint terbentuk 323
#  jumlah keypoint terbentuk 244
#  jumlah keypoint terbentuk 244
#  jumlah keypoint terbentuk 263
#  jumlah keypoint terbentuk 263
#  jumlah keypoint terbentuk 274
#  jumlah keypoint terbentuk 246
#  jumlah keypoint terbentuk 308
#  jumlah keypoint terbentuk 299
#  jumlah keypoint terbentuk 265
#  jumlah keypoint terbentuk 265
#  jumlah keypoint terbentuk 261
#  jumlah keypoint terbentuk 261
#  jumlah keypoint terbentuk 273
#  jumlah keypoint terbentuk 273
#  jumlah keypoint terbentuk 242
#  jumlah keypoint terbentuk 265
#  jumlah keypoint terbentuk 252
#  jumlah keypoint terbentuk 244
#  jumlah keypoint terbentuk 245
#  jumlah keypoint terbentuk 213
#  jumlah keypoint terbentuk 213
#  jumlah keypoint terbentuk 213
#  jumlah keypoint terbentuk 251
#  jumlah keypoint terbentuk 219
#  jumlah keypoint terbentuk 196
#  jumlah keypoint terbentuk 266
#  jumlah keypoint terbentuk 268
#  jumlah keypoint terbentuk 268
#  jumlah keypoint terbentuk 271
#  jumlah keypoint terbentuk 268
#  jumlah keypoint terbentuk 270
#  jumlah keypoint terbentuk 266
#  jumlah keypoint terbentuk 264
#  jumlah keypoint terbentuk 230
#  jumlah keypoint terbentuk 241
#  jumlah keypoint terbentuk 268
#  jumlah keypoint terbentuk 243
#  jumlah keypoint terbentuk 258
#  jumlah keypoint terbentuk 269
#  jumlah keypoint terbentuk 240
#  jumlah keypoint terbentuk 254
#  jumlah keypoint terbentuk 254
#  jumlah keypoint terbentuk 263
#  jumlah keypoint terbentuk 239
#  jumlah keypoint terbentuk 241
#  jumlah keypoint terbentuk 263
#  jumlah keypoint terbentuk 258
#  jumlah keypoint terbentuk 254
#  jumlah keypoint terbentuk 255
#  jumlah keypoint terbentuk 260
#  jumlah keypoint terbentuk 260
#  jumlah keypoint terbentuk 249
#  jumlah keypoint terbentuk 272
#  jumlah keypoint terbentuk 248
#  jumlah keypoint terbentuk 253
#  jumlah keypoint terbentuk 253
#  jumlah keypoint terbentuk 154
#  jumlah keypoint terbentuk 154
#  jumlah keypoint terbentuk 122
#  jumlah keypoint terbentuk 101
#  jumlah keypoint terbentuk 117
#  jumlah keypoint terbentuk 96
#  jumlah keypoint terbentuk 96
#  jumlah keypoint terbentuk 72
#  jumlah keypoint terbentuk 123
#  jumlah keypoint terbentuk 123
#  jumlah keypoint terbentuk 273
#  jumlah keypoint terbentuk 269
#  jumlah keypoint terbentuk 163
#  jumlah keypoint terbentuk 163
#  jumlah keypoint terbentuk 188
#  jumlah keypoint terbentuk 173
#  jumlah keypoint terbentuk 173
#  jumlah keypoint terbentuk 172
#  jumlah keypoint terbentuk 191
#  jumlah keypoint terbentuk 201
#  jumlah keypoint terbentuk 198
#  jumlah keypoint terbentuk 182
#  jumlah keypoint terbentuk 186
#  jumlah keypoint terbentuk 186
#  jumlah keypoint terbentuk 199
#  jumlah keypoint terbentuk 199
#  jumlah keypoint terbentuk 150
#  jumlah keypoint terbentuk 155
#  jumlah keypoint terbentuk 130
#  jumlah keypoint terbentuk 246
#  jumlah keypoint terbentuk 246
#  jumlah keypoint terbentuk 92
#  jumlah keypoint terbentuk 182
#  jumlah keypoint terbentuk 182
#  jumlah keypoint terbentuk 230
#  jumlah keypoint terbentuk 109
#  jumlah keypoint terbentuk 71
#  jumlah keypoint terbentuk 85
#  jumlah keypoint terbentuk 103
#  jumlah keypoint terbentuk 154
#  jumlah keypoint terbentuk 159
#  jumlah keypoint terbentuk 159
#  jumlah keypoint terbentuk 140
#  jumlah keypoint terbentuk 142
#  jumlah keypoint terbentuk 149
#  jumlah keypoint terbentuk 149
#  jumlah keypoint terbentuk 94
#  jumlah keypoint terbentuk 97
#  jumlah keypoint terbentuk 131
#  jumlah keypoint terbentuk 131
#  jumlah keypoint terbentuk 83
#  jumlah keypoint terbentuk 61
#  jumlah keypoint terbentuk 135
#  jumlah keypoint terbentuk 151
#  jumlah keypoint terbentuk 188
#  jumlah keypoint terbentuk 188
#  jumlah keypoint terbentuk 163
#  jumlah keypoint terbentuk 163
#  jumlah keypoint terbentuk 197
#  jumlah keypoint terbentuk 190
#  jumlah keypoint terbentuk 155
#  jumlah keypoint terbentuk 155
#  jumlah keypoint terbentuk 214
#  jumlah keypoint terbentuk 126
#  jumlah keypoint terbentuk 155
#  jumlah keypoint terbentuk 155
#  jumlah keypoint terbentuk 203
#  jumlah keypoint terbentuk 203
#  jumlah keypoint terbentuk 212
#  jumlah keypoint terbentuk 230
#  jumlah keypoint terbentuk 229
#  jumlah keypoint terbentuk 229
#  jumlah keypoint terbentuk 263
#  jumlah keypoint terbentuk 263
#  jumlah keypoint terbentuk 255
#  jumlah keypoint terbentuk 265
#  jumlah keypoint terbentuk 251
#  jumlah keypoint terbentuk 251
#  jumlah keypoint terbentuk 262
#  jumlah keypoint terbentuk 279
#  jumlah keypoint terbentuk 248
#  jumlah keypoint terbentuk 204
#  jumlah keypoint terbentuk 168
#  jumlah keypoint terbentuk 130
#  jumlah keypoint terbentuk 215
#  jumlah keypoint terbentuk 215
#  jumlah keypoint terbentuk 114
#  jumlah keypoint terbentuk 114
#  jumlah keypoint terbentuk 224
#  jumlah keypoint terbentuk 163
#  jumlah keypoint terbentuk 163
#  jumlah keypoint terbentuk 153
#  jumlah keypoint terbentuk 158
#  jumlah keypoint terbentuk 158
#  jumlah keypoint terbentuk 131
#  jumlah keypoint terbentuk 145
#  jumlah keypoint terbentuk 145
#  jumlah keypoint terbentuk 151
#  jumlah keypoint terbentuk 151
#  jumlah keypoint terbentuk 142
#  jumlah keypoint terbentuk 134
#  jumlah keypoint terbentuk 147
#  jumlah keypoint terbentuk 147
#  jumlah keypoint terbentuk 134
#  jumlah keypoint terbentuk 149
#  jumlah keypoint terbentuk 149
#  jumlah keypoint terbentuk 132
#  jumlah keypoint terbentuk 124
#  jumlah keypoint terbentuk 158
#  jumlah keypoint terbentuk 157
#  jumlah keypoint terbentuk 157
#  jumlah keypoint terbentuk 145
#  jumlah keypoint terbentuk 136
#  jumlah keypoint terbentuk 136
#  jumlah keypoint terbentuk 145
#  jumlah keypoint terbentuk 44
#  jumlah keypoint terbentuk 75
#  jumlah keypoint terbentuk 84
#  jumlah keypoint terbentuk 84
#  jumlah keypoint terbentuk 134
#  jumlah keypoint terbentuk 87
#  jumlah keypoint terbentuk 77
#  jumlah keypoint terbentuk 77
#  jumlah keypoint terbentuk 104
#  jumlah keypoint terbentuk 0
#  jumlah keypoint terbentuk 96
#  jumlah keypoint terbentuk 96
#  jumlah keypoint terbentuk 168
#  jumlah keypoint terbentuk 132
#  jumlah keypoint terbentuk 115
#  jumlah keypoint terbentuk 94
#  jumlah keypoint terbentuk 79
#  jumlah keypoint terbentuk 79
#  jumlah keypoint terbentuk 131
#  jumlah keypoint terbentuk 134
#  jumlah keypoint terbentuk 134
#  jumlah keypoint terbentuk 95
#  jumlah keypoint terbentuk 95
#  jumlah keypoint terbentuk 220
#  jumlah keypoint terbentuk 197
#  jumlah keypoint terbentuk 194
#  jumlah keypoint terbentuk 231
#  jumlah keypoint terbentuk 231
#  jumlah keypoint terbentuk 192
#  jumlah keypoint terbentuk 190
#  jumlah keypoint terbentuk 190
#  jumlah keypoint terbentuk 178
#  jumlah keypoint terbentuk 198
#  jumlah keypoint terbentuk 198
#  jumlah keypoint terbentuk 222
#  jumlah keypoint terbentuk 240
#  jumlah keypoint terbentuk 150
#  jumlah keypoint terbentuk 150
#  jumlah keypoint terbentuk 286
#  jumlah keypoint terbentuk 236
#  jumlah keypoint terbentuk 288
#  jumlah keypoint terbentuk 160
#  jumlah keypoint terbentuk 125
#  jumlah keypoint terbentuk 107
#  jumlah keypoint terbentuk 107
#  jumlah keypoint terbentuk 130
#  jumlah keypoint terbentuk 126
#  jumlah keypoint terbentuk 126
#  jumlah keypoint terbentuk 132
#  jumlah keypoint terbentuk 145
#  jumlah keypoint terbentuk 145
#  jumlah keypoint terbentuk 166
#  jumlah keypoint terbentuk 69
#  jumlah keypoint terbentuk 145
#  jumlah keypoint terbentuk 145
#  jumlah keypoint terbentuk 277
#  jumlah keypoint terbentuk 151
#  jumlah keypoint terbentuk 248
#  jumlah keypoint terbentuk 248
#  jumlah keypoint terbentuk 253
#  jumlah keypoint terbentuk 253
#  jumlah keypoint terbentuk 212
#  jumlah keypoint terbentuk 189
#  jumlah keypoint terbentuk 130
#  jumlah keypoint terbentuk 237
#  jumlah keypoint terbentuk 163
#  jumlah keypoint terbentuk 237
#  jumlah keypoint terbentuk 163
#  jumlah keypoint terbentuk 96
#  jumlah keypoint terbentuk 96
#  jumlah keypoint terbentuk 64
#  jumlah keypoint terbentuk 90
#  jumlah keypoint terbentuk 181
#  jumlah keypoint terbentuk 205
#  jumlah keypoint terbentuk 205
#  jumlah keypoint terbentuk 143
#  jumlah keypoint terbentuk 193
#  jumlah keypoint terbentuk 205
#  jumlah keypoint terbentuk 205
#  jumlah keypoint terbentuk 265
#  jumlah keypoint terbentuk 282
#  jumlah keypoint terbentuk 291
#  jumlah keypoint terbentuk 290
#  jumlah keypoint terbentuk 297
#  jumlah keypoint terbentuk 296
#  jumlah keypoint terbentuk 287
#  jumlah keypoint terbentuk 249
#  jumlah keypoint terbentuk 218
#  jumlah keypoint terbentuk 173
#  jumlah keypoint terbentuk 211
#  jumlah keypoint terbentuk 149
#  jumlah keypoint terbentuk 66
#  jumlah keypoint terbentuk 66
#  jumlah keypoint terbentuk 159
#  jumlah keypoint terbentuk 159
#  jumlah keypoint terbentuk 129
#  jumlah keypoint terbentuk 129
#  jumlah keypoint terbentuk 181
#  jumlah keypoint terbentuk 244
#  jumlah keypoint terbentuk 209
#  jumlah keypoint terbentuk 187
#  jumlah keypoint terbentuk 269
#  jumlah keypoint terbentuk 253
#  jumlah keypoint terbentuk 268
#  jumlah keypoint terbentuk 269
#  jumlah keypoint terbentuk 264
#  jumlah keypoint terbentuk 255
#  jumlah keypoint terbentuk 257
#  jumlah keypoint terbentuk 309
#  jumlah keypoint terbentuk 309
#  jumlah keypoint terbentuk 291
#  jumlah keypoint terbentuk 283
#  jumlah keypoint terbentuk 283
#  jumlah keypoint terbentuk 292
#  jumlah keypoint terbentuk 279
#  jumlah keypoint terbentuk 279
#  jumlah keypoint terbentuk 295
#  jumlah keypoint terbentuk 292
#  jumlah keypoint terbentuk 292
#  jumlah keypoint terbentuk 328
#  jumlah keypoint terbentuk 256
#  jumlah keypoint terbentuk 278
#  jumlah keypoint terbentuk 298
#  jumlah keypoint terbentuk 295
#  jumlah keypoint terbentuk 287
#  jumlah keypoint terbentuk 288
#  jumlah keypoint terbentuk 292
#  jumlah keypoint terbentuk 284
#  jumlah keypoint terbentuk 294
#  jumlah keypoint terbentuk 294
#  jumlah keypoint terbentuk 287
#  jumlah keypoint terbentuk 287
#  jumlah keypoint terbentuk 162
#  jumlah keypoint terbentuk 162
#  jumlah keypoint terbentuk 144
#  jumlah keypoint terbentuk 126
#  jumlah keypoint terbentuk 126
#  jumlah keypoint terbentuk 140
#  jumlah keypoint terbentuk 140
#  jumlah keypoint terbentuk 71
#  jumlah keypoint terbentuk 78
#  jumlah keypoint terbentuk 78
#  jumlah keypoint terbentuk 214
#  jumlah keypoint terbentuk 169
#  jumlah keypoint terbentuk 169
#  jumlah keypoint terbentuk 199
#  jumlah keypoint terbentuk 136
#  jumlah keypoint terbentuk 183
#  jumlah keypoint terbentuk 183
#  jumlah keypoint terbentuk 171
#  jumlah keypoint terbentuk 171
#  jumlah keypoint terbentuk 126
#  jumlah keypoint terbentuk 145
#  jumlah keypoint terbentuk 145
#  jumlah keypoint terbentuk 256
#  jumlah keypoint terbentuk 256
#  jumlah keypoint terbentuk 205
#  jumlah keypoint terbentuk 285
#  jumlah keypoint terbentuk 198
#  jumlah keypoint terbentuk 198
#  jumlah keypoint terbentuk 216
#  jumlah keypoint terbentuk 216
#  jumlah keypoint terbentuk 216
#  jumlah keypoint terbentuk 216
#  jumlah keypoint terbentuk 198
#  jumlah keypoint terbentuk 191
#  jumlah keypoint terbentuk 257
#  jumlah keypoint terbentuk 257
#  jumlah keypoint terbentuk 147
#  jumlah keypoint terbentuk 243
#  jumlah keypoint terbentuk 122
#  jumlah keypoint terbentuk 125
#  jumlah keypoint terbentuk 125
#  jumlah keypoint terbentuk 191
#  jumlah keypoint terbentuk 213
#  jumlah keypoint terbentuk 213
#  jumlah keypoint terbentuk 262
#  jumlah keypoint terbentuk 137
#  jumlah keypoint terbentuk 303
#  jumlah keypoint terbentuk 186
#  jumlah keypoint terbentuk 335
#  jumlah keypoint terbentuk 271
#  jumlah keypoint terbentuk 301
#  jumlah keypoint terbentuk 203
#  jumlah keypoint terbentuk 248
#  jumlah keypoint terbentuk 276
#  jumlah keypoint terbentuk 206
#  jumlah keypoint terbentuk 198
#  jumlah keypoint terbentuk 198
#  jumlah keypoint terbentuk 247
#  jumlah keypoint terbentuk 185
#  jumlah keypoint terbentuk 235
#  jumlah keypoint terbentuk 184
#  jumlah keypoint terbentuk 344
#  jumlah keypoint terbentuk 315
#  jumlah keypoint terbentuk 329
#  jumlah keypoint terbentuk 325
#  jumlah keypoint terbentuk 374
#  jumlah keypoint terbentuk 356
#  jumlah keypoint terbentuk 289
#  jumlah keypoint terbentuk 302
#  jumlah keypoint terbentuk 316
#  jumlah keypoint terbentuk 267
#  jumlah keypoint terbentuk 396
#  jumlah keypoint terbentuk 261
#  jumlah keypoint terbentuk 379
#  jumlah keypoint terbentuk 266
#  jumlah keypoint terbentuk 326
#  jumlah keypoint terbentuk 325
#  jumlah keypoint terbentuk 276
#  jumlah keypoint terbentuk 211
#  jumlah keypoint terbentuk 170
#  jumlah keypoint terbentuk 190
#  jumlah keypoint terbentuk 211
#  jumlah keypoint terbentuk 211
#  jumlah keypoint terbentuk 271
#  jumlah keypoint terbentuk 333
#  jumlah keypoint terbentuk 339
#  jumlah keypoint terbentuk 312
#  jumlah keypoint terbentuk 326
#  jumlah keypoint terbentuk 338
#  jumlah keypoint terbentuk 252
#  jumlah keypoint terbentuk 249
#  jumlah keypoint terbentuk
#  jumlah keypoint terbentuk 237
#  jumlah keypoint terbentuk 237
#  jumlah keypoint terbentuk 264
#  jumlah keypoint terbentuk 264
#  jumlah keypoint terbentuk 216
#  jumlah keypoint terbentuk 196
#  jumlah keypoint terbentuk 214
#  jumlah keypoint terbentuk 214
#  jumlah keypoint terbentuk 221
#  jumlah keypoint terbentuk 205
#  jumlah keypoint terbentuk 198
#  jumlah keypoint terbentuk 198
#  jumlah keypoint terbentuk 218
#  jumlah keypoint terbentuk 214
#  jumlah keypoint terbentuk 207
#  jumlah keypoint terbentuk 209
#  jumlah keypoint terbentuk 218
#  jumlah keypoint terbentuk 218
#  jumlah keypoint terbentuk 232
#  jumlah keypoint terbentuk 232
#  jumlah keypoint terbentuk 226
#  jumlah keypoint terbentuk 194
#  jumlah keypoint terbentuk 190
#  jumlah keypoint terbentuk 190
#  jumlah keypoint terbentuk 226
#  jumlah keypoint terbentuk 179
#  jumlah keypoint terbentuk 179
#  jumlah keypoint terbentuk 175
#  jumlah keypoint terbentuk 175
#  jumlah keypoint terbentuk 129
#  jumlah keypoint terbentuk 16
#  jumlah keypoint terbentuk 16

# %%
import cv2
import os
import os.path
import numpy as np
from time import sleep
import pickle

def read_model(filename, path=""):
    with open(os.path.join(path, filename), 'rb') as in_name:
        model = pickle.load(in_name)
        return model
    

color = (255, 0, 0)
video_path = input("Masukkan path video: ")  # Meminta pengguna untuk memasukkan path video
cap = cv2.VideoCapture(video_path)  # Membaca video dari file yang ditentukan

model = read_model("C:/Users/Reza/miniconda3/envs/LatihanCV/weight/model_haar_sift_knn_optimasi.pkl", path="") #load model
label_dict = np.load('C:/Users/Reza/miniconda3/envs/LatihanCV/weight/label_knn.npy', allow_pickle=True).item() #load label


while (cap.isOpened()):
    ret , frame = cap.read() #baca video dengan looping gambar
    if ret:
        face_roi = []# Load Haar Cascade classifier for face detection
        face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
        # Convert the image to grayscale (required for face detection)
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

        # Detect faces in the image using the face_cascade
        faces = face_cascade.detectMultiScale(gray, scaleFactor=1.5, minNeighbors=5)
        # Draw bounding boxes around the detected faces and display the image
        for (x, y, w, h) in faces:
            # Draw a rectangle around the detected face
            face_roi = frame[y:y+h, x:x+w]
            cv2.rectangle(frame, (x-5, y-5), (x + w+5, y + h+5), (0, 255, 0), 4)#beri rectangle dan beri overlap sebesar 5
            muka = cv2.resize(face_roi, (225,225), interpolation = cv2.INTER_AREA)#wajib sama dengan citra inputan trainer
            #sift
            sift = cv2.SIFT_create(nfeatures=500, nOctaveLayers=9, contrastThreshold=0.03, edgeThreshold=10, sigma=1.6)
            kpts, des = sift.detectAndCompute(muka, None)
            print(f" jumlah keypoint terbentuk {len(kpts)}")
            if(len(kpts) >= 200): #karna sistem akan akan menggunakan shape 200 minimal
                cv2.imshow("Haar",muka)
                # Marking the keypoint on the image using circles
                img=cv2.drawKeypoints(muka, kpts , muka ,flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
                # bovw
                #kmeans works only on float, so convert integers to float
                descriptors_float = des.astype(float)  
                # Perform k-means clustering and vector quantization
                from scipy.cluster.vq import kmeans, vq
                k = 200  #dari total 500 diambil hanya 200
                voc, variance = kmeans(obs=descriptors_float, k_or_guess=k, iter=5) 
                # Calculate the histogram of features and represent them as vector
                #vq Assigns codes from a code book to observations.
                im_features = np.zeros((1, k), "float32")
                for i in range(1):
                    words, distance = vq(des,voc)
                    for w in words:
                        im_features[i][w] += 1
                
                cv2.imshow("Sift",img)
                prediksi= model.predict(im_features) #prediksi
                key_found = [key for key, value in label_dict.items() if value == prediksi] #dapatkan namanya
                cv2.putText(frame, f"Deteksi : {key_found[0]}", (20, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255),2)
        cv2.imshow("Video Original" , frame)
    else:
        print('no video')
        cap.set(cv2.CAP_PROP_POS_FRAMES, 0)
        continue

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
    
cap.release()
cv2.destroyAllWindows()
cv2.waitKey(1)
